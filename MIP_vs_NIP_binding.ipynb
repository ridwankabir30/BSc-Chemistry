# %% [markdown]
# # 🧬 MIP vs NIP Binding Energy Analysis
# This notebook calculates the binding energy of MIP and NIP complexes with fluorescein using Gaussian single point energies.

# %%
import re
def extract_energy(log_file):
    with open(log_file, 'r') as file:
        for line in file:
            if 'SCF Done' in line:
                energy = float(line.split()[4])
                return energy
    return None

# Example usage (once .log files are ready)
# E_mip = extract_energy('mip_complex.log')
# E_nip = extract_energy('nip_complex.log')
# E_fluorescein = extract_energy('fluorescein.log')

# %%
# Binding energy calculation template
# BE_mip = E_mip - (E_fluorescein + E_polymer_blank)
# BE_nip = E_nip - (E_fluorescein + E_polymer_blank)
# print(f"MIP Binding Energy: {BE_mip:.3f} Hartree")
# print(f"NIP Binding Energy: {BE_nip:.3f} Hartree")

# %% [markdown]
# ### 📌 Interpretation
# > A more negative binding energy for the MIP complex indicates a stronger interaction with fluorescein due to successful imprinting.
